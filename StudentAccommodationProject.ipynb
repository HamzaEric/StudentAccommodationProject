# %%
#getpass module to securely handle password input.
import getpass
import random
import datetime

names=["Bob Maina","Peter Gachuki","Hamza Maina","Khadija Anab","Kelsey Omondi","Victorine Chepchirchir","Baylen Chilopa","George Mwaura","Jamalluddin Osman","Hussein Hamza"]
chosen_name=random.choice(names)

special_code=[1012,3456,566,899,5678,3445,56654,64443,433454,34323,45534,677765,4322,6788,2345,23443]
chosen_special_code=random.choice(special_code)

institution=["eMobilis Tech School","Moringa School","University of Nairobi","Kenyatta University","USIU","Kenya Methodist University","Multimedia University","Dawamu School","Kenya Muslim School"]
chosen_institution=random.choice(institution)

parents_guardian_names=["John Richard","Hassan Anab","Brian Ouma","Aisha Adano","Melody Njeri","Ramses Kimani","Cyprian Kings","Terence Kinyua","Abdikadir Osman","Darweish Abdijabar"]
chosen_parents_names=random.choice(parents_guardian_names)

unique_invoice_code=[2222,4322,56767,455435,67654,644554,46654,4665,44345,455445,65544,65465,75466,554565,466555,66556,6556,55566,5665666,5445566,766554,776546,3456,7665]
chosen_unique_invoice_code=random.choice(unique_invoice_code)

room_number=[1000,1001,1020,1318,1356,1345,1234,2345,456,789,2346,4576,3345,1800,7890,9090,4560,1433,1500,1600,1700,3000,4000,5000,6000,7000,8000,9000,9009,5678]
chosen_room_number=random.choice(room_number)

promotional_message = " Exciting News! Stay with us for three consecutive months and get TWO MONTHS of rent for FREE! Don't miss out on this amazing offer!"

laundry_prices = {
    "2kg": 200.00,  # 2 kilograms costs 200.00
    "4kg": 800.00,  # 4 kilograms costs 800.00
    "6kg": 1100.00, # 6 kilograms costs 1100.00
    "8kg": 1400.00, # 8 kilograms costs 1400.00
    "10kg": 1700.00 # 10 kilograms costs 1700.00
}

fun_events = {
    "Monday": "Movie Night ",
    "Wednesday": "Game Night ",
    "Friday": "Pizza Party ",
    "Saturday": "Talent Show ",
    "Sunday": "Study Group "
}

cafe_menu = {
    "Pancakes ": 500,
    "Burger ": 750,
    "Pizza Slice ": 300,
    "Chicken Salad Sandwich ": 600,
    "Pasta ": 800,
    "Fruit Salad ": 450,
    "Juice ": 250,
    "Cookies ": 150
}

set_rent=16500
set_wallet=0.00
gym_membership_fee=3500
set_deposit=16500
key_card_replacement_fee=500

#This shows the current date and time of any payments at the reception
def show_time_and_date():
    now = datetime.datetime.now()
    current_time = now.strftime("%H:%M:%S")
    current_date = now.strftime("%Y-%m-%d")
    time_and_date=(current_date,current_time)
    return time_and_date

today_date, now_time = show_time_and_date()


def entry_page():
    users = {}
    #We start with an empty dictionary called users.
    #This is where we'll keep track of all the people who have registered or logged in. It's like a digital guest book!
    print("Raha Stays Student Accommodation(Where there is a home away from home)")

    for i in range(5):
      #We're going to give our guests 5 chances to choose from the menu
        print("\n1. Login(Already a member)\n2. Register(You are a new member)\n3. Forgot Password\n4. Exit")
        choice = input("Select an option: ")

        if choice == "1":
            email = input("Enter Email: ")
            password = getpass.getpass("Enter Password: ")
           #We check if their email and password are in our "users" storage dictionary.
            if email in users and users[email]['password'] == password:
              #If they match, we take them to the "home menu" (like their room).
                home_menu(users[email])
            else:
                print("Invalid email and password.Try again.")

        elif choice == "2":
            email = input("Enter Email: ")
            #Check whether the email is in the users dictionarythis means a new member cannot use an already accredited email
            if email in users:
                print("The Email entered is already accredited to another user")
            else:
                password = getpass.getpass("Create Password: ")
                users[email] = {'password': password, 'profile': {}, 'financials': {}, 'bookings': []}
                print("Registration successful! Please login.")

        elif choice == "3":
            email = input("Enter your registered Email: ")
            #If we find their email, we let them create a new password and update our users dictionary.
            if email in users:
                new_password = getpass.getpass("Enter new password: ")
                users[email]['password'] = new_password
                print("Password updated successfully!")
            else:
                print("Email not found in the users dictionary")
        #if the user choose option 4 we display goodbye and we stop the program
        elif choice == "4":
            print("Exiting... Goodbye!")
            break
        #the invalid choice is displayed when the user inputs a number which is not displayed as an option
        else:
            print("Invalid choice! Try again.")

#The home_menu is like the control panel for everything you can do in your dorm life!
def home_menu(user):
    print("\nWelcome to Raha Stays Student Accommodation!")
    for i in range(5):
        print("\n1. My Home\n2. My Profile\n3. Important Documents\n4. Financials\n5. Bookings\n6. Logout")
        choice = input("Select an option: ")

        if choice == "1":
            my_home()
        elif choice == "2":
            my_profile(user)
        elif choice == "3":
            important_documents()
        elif choice == "4":
            financials()
        elif choice == "5":
            bookings()
        elif choice == "6":
            print("Logging out...")
            break
        else:
            print("Invalid choice! Try again.")

def my_home():
    print("\nMy Home")
    print(f"1. Current Booking(you are currently a raha stay member for one month from {today_date, now_time} if you would like to extend your stay consult the reception)\n2.Amount Due(Your bill is {set_rent})\n3.Wallet(Earn with rahaStays by refering your friends.Your current Wallet balance is{set_wallet})\n4.Maintenance Token(Post any problem in your room here eg lock problems)\n5. Electricity Token(this is covered in your rent)\n6. Invoice Summary(room type:Superior double room \n gym membership:N/A \n RENT FULLY PAID)")

    input("Select an option: ")

def my_profile(user):
    print("\nMy Profile")
    #everything that the user inputs is written down in the user profile
    user['profile']['User ID'] = input("Enter User ID: ")
    user['profile']['Date of Birth'] = input("Enter Date of Birth: ")
    user['profile']['Year of Study'] = input("Enter Year of Study: ")
    user['profile']['Email'] = input("Enter Email: ")
    user['profile']['Phone Number'] = input("Enter Phone Number: ")
    #The user['profile'] part is like a special section in your notebook where all your profile information goes.
    print("Profile updated successfully")

def important_documents():
    print("\nImportant Documents")
    print(f"1. Agreements(I as {chosen_name} declare to be in good conduct at RahaStays and that incase of any misconduct am ready to pay for the consequences).\n2. Birth Certificate(Due to Confidentialy of your birth certificate details.your code in reference to your birth certificate is {chosen_special_code}) (\n3. Student Proof(The Accommodation provided in RahaStays is for student only,so to proof you are a student in {chosen_institution} provide paycheck at the reception )")


def financials():
    print("\nFinancials")
    print(f"1. Payments(The payment for a superior double room made by {chosen_parents_names} on {today_date, now_time} has been payed successfully\n2. Invoice(Your unique  invoice code for your payment is {chosen_unique_invoice_code}.The code may change if the member logout of RahaStay)\)n3. Refund(Your deposit of {set_deposit} will be refunded at the end of your stay here at RahaStays)")

def bookings():
    print(f"\nBookings(room_number:{chosen_room_number}, if interested with a gym membership the fee is {gym_membership_fee} \n {promotional_message})")
    print(f"Details and periods of bookings (The fee charged for losing your room keycard is {key_card_replacement_fee} \n The Rent is paid after a month )")
    print(f"Speciality of Raha Stays:Laundry:{print(laundry_prices)} \n fun_events:{print(fun_events)} \n Raha_cafe_menu:{print(cafe_menu)}")

#This tells the program where to start
if __name__ == "__main__":
    entry_page()
# Out:
# Raha Stays Student Accommodation(Where there is a home away from home)
#
# 1. Login(Already a member)
# 2. Register(You are a new member)
# 3. Forgot Password
# 4. Exit
# Select an option: 2
# Enter Email: engari@gmail.com
# Create Password: ··········
# Registration successful! Please login.
#
# 1. Login(Already a member)
# 2. Register(You are a new member)
# 3. Forgot Password
# 4. Exit
# Select an option: 1
# Enter Email: engari@gmail.com
# Enter Password: ··········
#
# Welcome to Raha Stays Student Accommodation!
#
# 1. My Home
# 2. My Profile
# 3. Important Documents
# 4. Financials
# 5. Bookings
# 6. Logout
# Select an option: 1
#
# My Home
# 1. Current Booking(you are currently a raha stay member for one month from ('2025-02-23', '10:44:34') if you would like to extend your stay consult the reception)
# 2.Amount Due(Your bill is 16500)
# 3.Wallet(Earn with rahaStays by refering your friends.Your current Wallet balance is0.0)
# ...
